# %%
import main
import importlib

importlib.reload(main)

## Unstable stock data

## Data
tickers = ['VGT', 'AAPL', 'MSFT', 'NVDA', 'VOO', 'GME']
start_date = '2019-01-01'
split_date = '2023-01-01'
end_date_predict = '2023-03-01'

Compare = main.compare_all_models(tickers, [start_date, split_date, end_date_predict], save_results = True)

Compare.compute_metrics()
# Out:
# [*********************100%***********************]  1 of 1 completed
# d:\Side_projects\Quant finance 2026 Erdos\Project\main.py:240: UserWarning: feature_window shrunk 1000 -> 504: only 1008 training rows before 2023-01-01. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 16
#      12 end_date_predict = '2023-03-01'
#      13
#      14 Compare = main.compare_all_models(tickers, [start_date, split_date, end_date_predict], save_results = True)
#      15
# ---> 16 Compare.compute_metrics()
#      17
#      18
#      19
#
# File d:\Side_projects\Quant finance 2026 Erdos\Project\main.py:240, in compare_all_models.compute_metrics(self)
#     237 model_vol  = {}
#     239 for model_name in self.model_dic:
# --> 240     fits = self.model_dic[model_name].fit(data, self.split_date)
#     241     predicted_volatility = fits.test()
#     243     model_vol[model_name] = predicted_volatility
#
# File d:\Side_projects\Quant finance 2026 Erdos\Project\models\RF_model.py:86, in fit.__init__(self, df, test_start, features, window, target_name, target_window, lookback, lamb, winsorize, corr_threshold, lower_q, upper_q, rf_refine, grid_search, rf_params)
#      82     self.rf_params = rf_params
#      84 self.grid_search = grid_search
# ---> 86 self._fit(df, test_start)
#
# File d:\Side_projects\Quant finance 2026 Erdos\Project\models\RF_model.py:105, in fit._fit(self, df, start_test)
#      89 """
#      90     Fit model
#      91     df: pandas dataframe with column names Date, Open, Close, Volume, High, Low
#    (...)     95     end_test denotes end of test dates
#      96 """
#      97 self.df = (
#      98     df.stack(level=1, future_stack=True)
#      99       .reset_index()
#    (...)    103       })
#     104     )
# --> 105 self.df = df.sort_values(by=["Date"])
#     106 self.start_test = start_test
#     107 self.det_features()
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8359, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8355             )
#    8356         elif by:
#    8357             # len(by) == 1
#    8358
# -> 8359             k = self._get_label_or_level_values(by[0], axis=axis)
#    8360
#    8361             # need to rewrap column in Series to apply key function
#    8362             if key is not None:
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'Date'
