# %%
import main
import importlib

importlib.reload(main)

## tickers to look at
large_company_tickers = ['GOOG', 'AAPL', 'NVDA']
volatile_company_tickers = ["TSLA", "GME"]
stable_company_tickers = ["WMT", "JNJ"]

# time frames
stable_start = "2015-01-01" 
stable_end = "2018-12-31" 
unstable_start = "2019-01-01" 
unstable_end = "2022-12-31" 

# train/test split
stable_train_end = "2018-03-31" 
unstable_train_end = "2022-03-31"

# %%
# run stable 

Compare = main.compare_all_models(large_company_tickers, [stable_start, stable_train_end, stable_end], save_results = True)

Compare.compute_metrics()
# Out:
# [*********************100%***********************]  1 of 1 completed
# c:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 408: only 816 training rows before 2018-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# c:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 408: only 816 training rows before 2018-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
# run stable volatile companies

Compare = main.compare_all_models(volatile_company_tickers, [stable_start, stable_train_end, stable_end], save_results = True)

Compare.compute_metrics()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 408: only 816 training rows before 2018-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 408: only 816 training rows before 2018-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# Results saved to results\model_performance_comparison.csv

# %%
# run stable time and companies

Compare = main.compare_all_models(stable_company_tickers, [stable_start, stable_train_end, stable_end], save_results = True)

Compare.compute_metrics()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 408: only 816 training rows before 2018-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 408: only 816 training rows before 2018-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# Results saved to results\model_performance_comparison.csv

# %%
# run stable time and large company

Compare = main.compare_all_models(large_company_tickers, [unstable_start, unstable_train_end, unstable_end], save_results = True)

Compare.compute_metrics()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 409: only 818 training rows before 2022-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 409: only 818 training rows before 2022-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
# run stable time and volatile company
Compare = main.compare_all_models(volatile_company_tickers, [unstable_start, unstable_train_end, unstable_end], save_results = True)

Compare.compute_metrics()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 409: only 818 training rows before 2022-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 409: only 818 training rows before 2022-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# Results saved to results\model_performance_comparison.csv

# %%
# run unstable time and stable company
Compare = main.compare_all_models(stable_company_tickers, [unstable_start, unstable_train_end, unstable_end], save_results = True)

Compare.compute_metrics()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 409: only 818 training rows before 2022-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 409: only 818 training rows before 2022-03-31. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
