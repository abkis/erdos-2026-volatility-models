# %%
import main
import importlib

importlib.reload(main)

## Unstable stock data

## Data
tickers = ['VGT', 'AAPL', 'MSFT', 'NVDA', 'VOO', 'GME']
start_date = '2019-01-01'
split_date = '2023-01-01'
end_date_predict = '2023-03-01'

Compare = main.compare_all_models(tickers, [start_date, split_date, end_date_predict], save_results = True)

Compare.compute_metrics()
# Out:
# [*********************100%***********************]  1 of 1 completed
# c:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 504: only 1008 training rows before 2023-01-01. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# c:\Users\Owner\code\erdos-2026-volatility-models\main.py:240: UserWarning: feature_window shrunk 1000 -> 504: only 1008 training rows before 2023-01-01. Longer history gives the kernel more memory and more rows to fit on.
#   fits = self.model_dic[model_name].fit(data, self.split_date)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...
